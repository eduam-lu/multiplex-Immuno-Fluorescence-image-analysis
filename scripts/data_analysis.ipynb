# %% [markdown]
# # Patient Data Analysis

# %%
### MODULES ######################################################
import pandas as pd

# %%
### FUNCTIONS ####################################################

# %% [markdown]
# ## Load the dataframe
